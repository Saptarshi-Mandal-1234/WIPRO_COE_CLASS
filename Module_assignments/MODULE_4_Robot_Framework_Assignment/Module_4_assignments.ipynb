# %% [markdown]
# # Module 4: Robot Framework

# %% [markdown]
# ## Software and Libraries Required

# %%
# %pip install robotframework
# %pip install robotframework-seleniumlibrary
# %pip install selenium
# %pip install robotframework-datadriver
# Out:
# ...
#
# ...
#    ---------------------------------------- 0.0/842.5 kB ? eta -:--:--
#    ---------------------------------------- 842.5/842.5 kB 18.7 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [robotframework-pythonlibcore]
#    ------------------- ------------------- 1/2 [robotframework-seleniumlibrary]
#    ------------------- ------------------- 1/2 [robotframework-seleniumlibrary]
#    ------------------- ------------------- 1/2 [robotframework-seleniumlibrary]
#    --------------------------------------- 2/2 [robotframework-seleniumlibrary]
#
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
#    ---------------------------------------- 0.0/634.7 kB ? eta -:--:--
#    ---------------------------------------- 634.7/634.7 kB 12.0 MB/s  0:00:00
# ...
#
#    ---------------------------------------- 0/2 [docutils]
#    ---------------------------------------- 0/2 [docutils]
# ...

# %% [markdown]
# # Assignment 1: Basic Syntax and Keywords

# %% [markdown]
# ## Question 1: Open a Web Browser and Navigate to a URL

# %%
from pathlib import Path
import subprocess

module4 = Path("Module4_Robot_Framework")
module4.mkdir(exist_ok=True)

basic_syntax = """*** Settings ***
Library    SeleniumLibrary

*** Variables ***
${URL}       https://www.saucedemo.com/
${BROWSER}   Chrome

*** Test Cases ***
Open Browser And Navigate
    Open Browser    ${URL}    ${BROWSER}
    Maximize Browser Window
    Sleep    3s
    Page Should Contain    Swag Labs
    Sleep    3s
    Close Browser
"""

(module4 / "basic_syntax.robot").write_text(
    basic_syntax,
    encoding="utf-8"
)

result = subprocess.run(
    ["robot", "basic_syntax.robot"],
    cwd=module4,
    capture_output=True,
    text=True
)

print(result.stdout)

if result.stderr:
    print(result.stderr)
# Out:
# ...
# Basic Syntax
# ...
# Open Browser And Navigate                                             | PASS |
# ------------------------------------------------------------------------------
# Basic Syntax                                                          | PASS |
# 1 test, 1 passed, 0 failed
# ...
# Output:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\output.xml
# Log:     d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\log.html
# Report:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\report.html

# %% [markdown]
# ## Question 2: Use the Input Text Keyword

# %%
input_text_test = """*** Settings ***
Library    SeleniumLibrary

*** Variables ***
${URL}       https://www.saucedemo.com/
${BROWSER}   Chrome

*** Test Cases ***
Input Text In Form
    Open Browser    ${URL}    ${BROWSER}
    Maximize Browser Window
    Sleep    2s

    Input Text    id=user-name    standard_user
    Sleep    2s

    Input Text    id=password    secret_sauce
    Sleep    3s

    Close Browser
"""

(module4 / "input_text.robot").write_text(
    input_text_test,
    encoding="utf-8"
)

result = subprocess.run(
    ["robot", "input_text.robot"],
    cwd=module4,
    capture_output=True,
    text=True
)

print(result.stdout)

if result.stderr:
    print(result.stderr)
# Out:
# ...
# Input Text
# ...
# Input Text In Form                                                    | PASS |
# ------------------------------------------------------------------------------
# Input Text                                                            | PASS |
# 1 test, 1 passed, 0 failed
# ...
# Output:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\output.xml
# Log:     d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\log.html
# Report:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\report.html

# %% [markdown]
# ## Question 3: Verify the Presence of an Element

# %%
element_test = """*** Settings ***
Library    SeleniumLibrary

*** Variables ***
${URL}       https://www.saucedemo.com/
${BROWSER}   Chrome

*** Test Cases ***
Verify Element Presence
    Open Browser    ${URL}    ${BROWSER}
    Maximize Browser Window
    Sleep    2s

    Page Should Contain Element    id=user-name
    Sleep    3s

    Close Browser
"""

(module4 / "element_verification.robot").write_text(
    element_test,
    encoding="utf-8"
)

result = subprocess.run(
    ["robot", "element_verification.robot"],
    cwd=module4,
    capture_output=True,
    text=True
)

print(result.stdout)

if result.stderr:
    print(result.stderr)
# Out:
# ...
# Element Verification
# ...
# Verify Element Presence                                               | PASS |
# ------------------------------------------------------------------------------
# Element Verification                                                  | PASS |
# 1 test, 1 passed, 0 failed
# ...
# Output:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\output.xml
# Log:     d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\log.html
# Report:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\report.html

# %% [markdown]
# # Assignment 2: Variables and Data-Driven Automation

# %% [markdown]
# ## Question 4: Using Variables

# %%
variables_test = """*** Settings ***
Library    SeleniumLibrary

*** Variables ***
${URL}       https://www.saucedemo.com/
${BROWSER}   Chrome
${USERNAME}  standard_user
${PASSWORD}  secret_sauce

*** Test Cases ***
Login Using Variables
    Open Browser    ${URL}    ${BROWSER}
    Maximize Browser Window
    Sleep    2s

    Input Text    id=user-name    ${USERNAME}
    Sleep    2s

    Input Text    id=password    ${PASSWORD}
    Sleep    2s

    Click Button    id=login-button
    Sleep    4s

    Page Should Contain    Products
    Sleep    3s

    Close Browser
"""

(module4 / "variables_test.robot").write_text(
    variables_test,
    encoding="utf-8"
)

result = subprocess.run(
    ["robot", "variables_test.robot"],
    cwd=module4,
    capture_output=True,
    text=True
)

print(result.stdout)

if result.stderr:
    print(result.stderr)
# Out:
# ...
# Variables Test
# ...
# Login Using Variables                                                 | PASS |
# ------------------------------------------------------------------------------
# Variables Test                                                        | PASS |
# 1 test, 1 passed, 0 failed
# ...
# Output:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\output.xml
# Log:     d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\log.html
# Report:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\report.html

# %% [markdown]
# ## Question 5: Data-Driven Automation

# %%
csv_data = """${username},${password}
standard_user,secret_sauce
problem_user,secret_sauce
performance_glitch_user,secret_sauce
"""

(module4 / "test_data.csv").write_text(
    csv_data,
    encoding="utf-8"
)

print("test_data.csv created successfully.")
print((module4 / "test_data.csv").read_text())
# Out:
# test_data.csv created successfully.
# ${username},${password}
# standard_user,secret_sauce
# problem_user,secret_sauce
# performance_glitch_user,secret_sauce

# %%
data_driven_test = """*** Settings ***
Library    SeleniumLibrary
Library    DataDriver    file=test_data.csv
Test Template    Login Test

*** Variables ***
${URL}       https://www.saucedemo.com/
${BROWSER}   Chrome

*** Test Cases ***
Login Test
    ${username}    ${password}

*** Keywords ***
Login Test
    [Arguments]    ${username}    ${password}

    Open Browser    ${URL}    ${BROWSER}
    Maximize Browser Window
    Sleep    2s

    Input Text    id=user-name    ${username}
    Sleep    1s

    Input Text    id=password    ${password}
    Sleep    1s

    Click Button    id=login-button
    Sleep    4s

    Page Should Contain    Products
    Sleep    3s

    Close Browser
"""

(module4 / "data_driven.robot").write_text(
    data_driven_test,
    encoding="utf-8"
)

result = subprocess.run(
    ["robot", "data_driven.robot"],
    cwd=module4,
    capture_output=True,
    text=True
)

print(result.stdout)

if result.stderr:
    print(result.stderr)
# Out:
# ...
# Data Driven
# ...
# Login Test                                                            | FAIL |
# Test cannot be empty.
# ------------------------------------------------------------------------------
# Data Driven                                                           | FAIL |
# 1 test, 0 passed, 1 failed
# ...
# Output:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\output.xml
# Log:     d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\log.html
# Report:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\report.html
#
# [ ERROR ] [ DataDriver ] Error in robot file:
#   File "d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\data_driven.robot", line 0
# [ ERROR ] In source file:
# ...

# %% [markdown]
# # Assignment 3: Custom Keywords and Libraries

# %% [markdown]
# ## Question 6: Create a Custom Robot Framework Keyword Using Python

# %%
custom_python = """class CustomKeywords:

    def calculate_sum(self, a, b):
        return int(a) + int(b)
"""

(module4 / "custom_keywords.py").write_text(
    custom_python,
    encoding="utf-8"
)

print("custom_keywords.py created successfully.")
# Out:
# custom_keywords.py created successfully.

# %% [markdown]
# ### Using the Custom Python Library

# %%
custom_robot_test = """*** Settings ***
Library    custom_keywords.py

*** Test Cases ***
Calculate Sum Using Custom Keyword
    ${result}=    Calculate Sum    10    20
    Log    The calculated sum is ${result}
    Should Be Equal As Integers    ${result}    30
"""

(module4 / "custom_keyword_test.robot").write_text(
    custom_robot_test,
    encoding="utf-8"
)

result = subprocess.run(
    ["robot", "custom_keyword_test.robot"],
    cwd=module4,
    capture_output=True,
    text=True
)

print(result.stdout)

if result.stderr:
    print(result.stderr)
# Out:
# ...
# Custom Keyword Test
# ...
# Calculate Sum Using Custom Keyword                                    | FAIL |
# No keyword with name 'Calculate Sum' found.
# ------------------------------------------------------------------------------
# Custom Keyword Test                                                   | FAIL |
# 1 test, 0 passed, 1 failed
# ...
# Output:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\output.xml
# Log:     d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\log.html
# Report:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\report.html
#
# [ WARN ] Imported library 'd:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\custom_keywords.py' contains no keywords.

# %% [markdown]
# ## Additional Custom Keyword Demonstration

# %%
custom_robot_multiple = """*** Settings ***
Library    custom_keywords.py

*** Test Cases ***
Calculate Multiple Sums
    ${result1}=    Calculate Sum    10    20
    Should Be Equal As Integers    ${result1}    30

    ${result2}=    Calculate Sum    25    15
    Should Be Equal As Integers    ${result2}    40

    ${result3}=    Calculate Sum    100    50
    Should Be Equal As Integers    ${result3}    150

    Log    All calculations completed successfully
"""

(module4 / "custom_keyword_multiple.robot").write_text(
    custom_robot_multiple,
    encoding="utf-8"
)

result = subprocess.run(
    ["robot", "custom_keyword_multiple.robot"],
    cwd=module4,
    capture_output=True,
    text=True
)

print(result.stdout)

if result.stderr:
    print(result.stderr)
# Out:
# ...
# Custom Keyword Multiple
# ...
# Calculate Multiple Sums                                               | FAIL |
# No keyword with name 'Calculate Sum' found.
# ------------------------------------------------------------------------------
# Custom Keyword Multiple                                               | FAIL |
# 1 test, 0 passed, 1 failed
# ...
# Output:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\output.xml
# Log:     d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\log.html
# Report:  d:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\report.html
#
# [ WARN ] Imported library 'd:\Pritam_Karak_C_22_Python_Selenium_Automation_Assignment_\MODULE_4_Robot_Framework_Assignment\Module4_Robot_Framework\custom_keywords.py' contains no keywords.

# %% [markdown]
# # Test Reports

# %%
result = subprocess.run(
    [
        "robot",
        "--output", "output.xml",
        "--log", "log.html",
        "--report", "report.html",
        "."
    ],
    cwd=module4,
    capture_output=True,
    text=True
)

print(result.stdout)

if result.stderr:
    print(result.stderr)
# Out:
# ...
# Module4 Robot Framework
# ...
# Module4 Robot Framework.Basic Syntax
# ...
# Open Browser And Navigate                                             | PASS |
# ------------------------------------------------------------------------------
# Module4 Robot Framework.Basic Syntax                                  | PASS |
# 1 test, 1 passed, 0 failed
# ...
# Module4 Robot Framework.Custom Keyword Multiple
# ...
# Calculate Multiple Sums                                               | FAIL |
# No keyword with name 'Calculate Sum' found.
# ------------------------------------------------------------------------------
# Module4 Robot Framework.Custom Keyword Multiple                       | FAIL |
# 1 test, 0 passed, 1 failed
# ...
# Module4 Robot Framework.Custom Keyword Test
# ...
# Calculate Sum Using Custom Keyword                                    | FAIL |
# No keyword with name 'Calculate Sum' found.
# ------------------------------------------------------------------------------
# ...

# %% [markdown]
# # Conclusion
