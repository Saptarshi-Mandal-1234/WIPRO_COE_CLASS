# %% [markdown]
# # Module 3 – Lab Work

# %% [markdown]
# # Assignment 1

# %% [markdown]
# ### Day 1: Environment Setup

# %% [markdown]
# Check python version

# %%
import sys

print("Python Version:")
print(sys.version)
# Out:
# Python Version:
# 3.11.4 (tags/v3.11.4:d2340ef, Jun  7 2023, 05:45:37) [MSC v.1934 64 bit (AMD64)]

# %% [markdown]
# Install the required libraries.

# %%
# %pip install selenium behave requests
# Out:
# ...
#
#    -------- ------------------------------- 1/5 [parse-type]
#    -------- ------------------------------- 1/5 [parse-type]
#    ------------------------ --------------- 3/5 [cucumber-expressions]
#    ------------------------ --------------- 3/5 [cucumber-expressions]
#    ------------------------ --------------- 3/5 [cucumber-expressions]
#    -------------------------------- ------- 4/5 [behave]
#    -------------------------------- ------- 4/5 [behave]
#    -------------------------------- ------- 4/5 [behave]
#    -------------------------------- ------- 4/5 [behave]
#    -------------------------------- ------- 4/5 [behave]
#    -------------------------------- ------- 4/5 [behave]
#    -------------------------------- ------- 4/5 [behave]
#    -------------------------------- ------- 4/5 [behave]
#    -------------------------------- ------- 4/5 [behave]
#    -------------------------------- ------- 4/5 [behave]
#    -------------------------------- ------- 4/5 [behave]
# ...

# %% [markdown]
# Check Selenium:

# %%
import selenium

print("Selenium version:", selenium.__version__)
# Out:
# Selenium version: 4.47.0

# %% [markdown]
# Check Behave:

# %%
import behave

print("Behave is installed successfully")
# Out:
# Behave is installed successfully

# %% [markdown]
# ## Introduction to BDD

# %% [markdown]
# ## Gherkin Example

# %% [markdown]
# ## Behave Project Structure

# %% [markdown]
# ## Result – Assignment 1

# %% [markdown]
# ## Day 1: QEMU and GDB Debugging

# %% [markdown]
# ### GDB Debugging Steps

# %% [markdown]
# # Day 2 – Execute the Scenario in the Simulated Environment

# %% [markdown]
# # Day 3 – Debugging the Scenario Using Eclipse and GDB

# %% [markdown]
# # Day 4 – Complete Scenario and Verify Results

# %% [markdown]
# # Assignment 1 – Final Result

# %% [markdown]
# # Assignment 2

# %% [markdown]
# ## Data-Driven Testing

# %% [markdown]
# ## Result

# %% [markdown]
# # Assignment 3 – Selenium Page Object Model in Python Behave Framework

# %% [markdown]
# ## Result

# %% [markdown]
# ## Conclusion
